# %% [markdown]
# <a href="https://colab.research.google.com/github/sairamsankranthi13-a11y/pandas-series/blob/main/pandas%20series2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#PANDAS SERIES WITH NaN values
print('NaN')
import numpy as np
import pandas as pd
a=[10,20,30,np.nan,60]
s=pd.Series(a)
print(s)

print()

#pandas object series with NaN
import numpy as np
import pandas as pd
n=["sai","ram","prasad",np.nan]
s=pd.Series(n)
print(s)

print()

#pandas SERIES ATTRIBUTES
print("values")

import pandas as pd
m=[23,45,56,77,89]
s=pd.Series(m)
print(s)
print(s.values)
print()

#pandas VALUES ATTRIBUTES
print( )
import pandas as pd
name=["sai","ram","ramu","prasad"]
s=pd.Series(name)
print(s)
print(s.values)

print()

#INDEX ATTRIBUTE
print("index")
import pandas as pd
m=[23,45,56,77,89]
s=pd.Series(m)
print(s)
print(s.index)

print()

#ACCESING INDEX ATTRIBUTE
print("accesing index")

import pandas as pd
a=[12,23,34,56,67]
i=[1,2,3,4,5,]
s=pd.Series(a,index=a)

print()
print(s.index)

#accesing Dtypes attribute
print("accesing Dtypes attribute")

import pandas as pd
a=[12,23,34,56,67]

s=pd.Series(a)
print(s)
print(s.dtypes)

print()

#accesing dypes attribute
print("accesing dypes attribute")

import pandas as pd
a=[12.0,23.0,34.0,56,67]

s=pd.Series(a)
print(s)
print(s.dtypes)

print()

#accesing dtypes attributes
print("accesing dtypes attributes")

import pandas as pd
a=["sai","ram","prasad","ramu","rani"]

s=pd.Series(a)
print(s)
print(s.dtypes)

print()

#accesing size attributes
print("accesing size attributes")

import pandas as pd
a=[12,34,45,65,67]

s=pd.Series(a)
print(s)
print(s.size)

print()
# Out:
# NaN
# 0    10.0
# 1    20.0
# 2    30.0
# 3     NaN
# 4    60.0
# dtype: float64
#
# 0       sai
# 1       ram
# 2    prasad
# 3       NaN
# dtype: object
#
# values
# 0    23
# 1    45
# 2    56
# 3    77
# 4    89
# dtype: int64
# [23 45 56 77 89]
#
#
# 0       sai
# 1       ram
# 2      ramu
# 3    prasad
# dtype: object
# ['sai' 'ram' 'ramu' 'prasad']
#
# index
# 0    23
# 1    45
# 2    56
# 3    77
# 4    89
# dtype: int64
# RangeIndex(start=0, stop=5, step=1)
#
# accesing index
#
# Index([12, 23, 34, 56, 67], dtype='int64')
# accesing Dtypes attribute
# 0    12
# 1    23
# 2    34
# 3    56
# 4    67
# dtype: int64
# int64
#
# accesing dypes attribute
# 0    12.0
# 1    23.0
# 2    34.0
# 3    56.0
# 4    67.0
# dtype: float64
# float64
#
# accesing dtypes attributes
# 0       sai
# 1       ram
# 2    prasad
# 3      ramu
# 4      rani
# dtype: object
# object
#
# accesing size attributes
# 0    12
# 1    34
# 2    45
# 3    65
# 4    67
# dtype: int64
# 5
